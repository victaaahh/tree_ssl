# %%
# %matplotlib widget
import geopandas as gpd
from torch_points3d.datasets.ssl.las_dataset import LasSSL
import matplotlib.pyplot as plt

# %%
dataset = LasSSL('data/treeSSL', ["2017/*.laz", "2020-21/*.laz"])

# %%
label_file = gpd.read_file('data/treeSSL/processed/label_files/0_179.gpkg')
label_file['index'] = label_file.index.values

# %%
label_file.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_def63348bd59cf22e51b3151d7187fc7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_def63348bd59cf22e51b3151d7187fc7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_def63348bd59cf22e51b3151d7187fc7 = L.map(
#                 &quot;map_def63348bd59cf22e51b3151d7187fc7&quot;,
#                 {
#                     center: [55.37518883378873, 11.548757155532675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_def63348bd59cf22e51b3151d7187fc7);
#
#
#
#
#
#             var tile_layer_9a409192c049877a70b5e301ed0a8dd6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9a409192c049877a70b5e301ed0a8dd6.addTo(map_def63348bd59cf22e51b3151d7187fc7);
#
#
#             map_def63348bd59cf22e51b3151d7187fc7.fitBounds(
#                 [[55.37087495303143, 11.540938855380427], [55.37950271454603, 11.556575455684923]],
#                 {}
#             );
#
#
#         function geo_json_744d4d7e8791b6818c5c5c15a3d85d72_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_744d4d7e8791b6818c5c5c15a3d85d72_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_744d4d7e8791b6818c5c5c15a3d85d72_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_744d4d7e8791b6818c5c5c15a3d85d72_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_744d4d7e8791b6818c5c5c15a3d85d72_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_744d4d7e8791b6818c5c5c15a3d85d72.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_744d4d7e8791b6818c5c5c15a3d85d72_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_744d4d7e8791b6818c5c5c15a3d85d72 = L.geoJson(null, {
#                 onEachFeature: geo_json_744d4d7e8791b6818c5c5c15a3d85d72_onEachFeature,
#
#                 style: geo_json_744d4d7e8791b6818c5c5c15a3d85d72_styler,
#                 pointToLayer: geo_json_744d4d7e8791b6818c5c5c15a3d85d72_pointToLayer,
#         });
#
#         function geo_json_744d4d7e8791b6818c5c5c15a3d85d72_add (data) {
#             geo_json_744d4d7e8791b6818c5c5c15a3d85d72
#                 .addData(data);
#         }
#             geo_json_744d4d7e8791b6818c5c5c15a3d85d72_add({&quot;bbox&quot;: [11.540938855380427, 55.37087495303143, 11.556575455684923, 55.37950271454603], &quot;features&quot;: [{&quot;bbox&quot;: [11.542778619116442, 55.37095374055388, 11.542778619116442, 55.37095374055388], &quot;geometry&quot;: {&quot;coordinates&quot;: [11.542778619116442, 55.37095374055388], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;index&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [11.543251510309906, 55.370943898511, 11.543251510309906, 55.370943898511], &quot;geometry&quot;: {&quot;coordinates&quot;: [11.543251510309906, 55.370943898511], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;index&quot;: 1}

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(*dataset[24].pos.T, s=0.1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dataset[220].pos.min(axis=0)
# Out:
# torch.return_types.min(
# values=tensor([-14.9100, -14.9000,   0.0000]),
# indices=tensor([ 397,  179, 2783]))

# %%
dataset[24]
# Out:
# Data(pos=[12340, 3])
